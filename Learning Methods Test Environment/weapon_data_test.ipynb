# %%
import weapon_data as weapons
# Out:
# D:\z_outsourced_programs\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data = weapons.DataSet(seed=19071991, show_debug=True)
# Out:
# Feature columns to tensor variables dictionary:
# _NumericColumn(key='damages_first', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='damages_last', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='dmg_distances_first', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='dmg_distances_last', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='drag', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='firemode', vocabulary_list=('Automatic', 'Semi-Automatic', 'Single-Action'), dtype=tf.string, default_value=-1, num_oov_buckets=0)) = []
# _NumericColumn(key='hiprecoildec', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='hiprecoilright', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='hiprecoilup', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='hordispersion', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='initialspeed', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='magsize', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='reloadempty', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='rof', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _NumericColumn(key='shotspershell', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
# _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='type', vocabulary_list=('Shotgun', 'Pistol', 'Rifle', 'Submachine Gun', 'Sniper Rifle', 'Light Machine Gun'), dtype=tf.string, default_value=-1, num_oov_buckets=0)) = []
# _NumericColumn(key='verdispersion', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None) = []
#
# Generated input with feature columns:
# Tensor("input_layer/concat:0", shape=(148, 24), dtype=float32)
#
# Found 24 features with 148 values in data source ./weapon_data.csv!

# %%
data.num_examples
# Out:
# 148

# %%
data.data
# Out:
# array([[ 7.7 ,  3.85, 12.  , ...,  0.  ,  0.  ,  1.2 ],
#        [ 7.7 ,  3.85, 14.  , ...,  0.  ,  0.  ,  1.8 ],
#        [ 7.7 ,  3.85, 14.  , ...,  0.  ,  0.  ,  1.2 ],
#        ...,
#        [90.  , 70.  ,  0.  , ...,  1.  ,  0.  ,  0.  ],
#        [90.  , 70.  ,  0.  , ...,  1.  ,  0.  ,  0.  ],
#        [23.  , 13.5 ,  6.  , ...,  0.  ,  0.  ,  0.  ]], dtype=float32)

# %%
import tensorflow as tf

genDict = {}

def addGeneratedWeapon(generatedWeaponTensorDict, dictToAdd):
    for key, value in generatedWeaponTensorDict.items():
        if key not in dictToAdd:
            dictToAdd[key] = []
        dictToAdd[key].append(value)


var_init = tf.global_variables_initializer()

batch_size = 1
with tf.Session() as sess:
    sess.run(var_init)
    
    for i in range(0,100):
        batch = data.next_batch(batch_size, shuffle=True)
        #print("Batch size %i" %len(batch))
        data.add_new_weapon(batch[0])
    
    tensorDict = [data.decode_processed_tensor(b) for b in batch]
    [addGeneratedWeapon(t, genDict) for t in tensorDict]
    #debug_printDict(tensorDict[0])
    
    
weapons.debug_printDict(genDict)
# Out:
# Current position in dataset after next_batch = 1
# Added new weapon/s! New number of examples in dataset = 149
# Current position in dataset after next_batch = 2
# Added new weapon/s! New number of examples in dataset = 150
# Current position in dataset after next_batch = 3
# Added new weapon/s! New number of examples in dataset = 151
# Current position in dataset after next_batch = 4
# Added new weapon/s! New number of examples in dataset = 152
# Current position in dataset after next_batch = 5
# Added new weapon/s! New number of examples in dataset = 153
# Current position in dataset after next_batch = 6
# Added new weapon/s! New number of examples in dataset = 154
# Current position in dataset after next_batch = 7
# Added new weapon/s! New number of examples in dataset = 155
# Current position in dataset after next_batch = 8
# Added new weapon/s! New number of examples in dataset = 156
# Current position in dataset after next_batch = 9
# Added new weapon/s! New number of examples in dataset = 157
# Current position in dataset after next_batch = 10
# Added new weapon/s! New number of examples in dataset = 158
# Current position in dataset after next_batch = 11
# Added new weapon/s! New number of examples in dataset = 159
# Current position in dataset after next_batch = 12
# Added new weapon/s! New number of examples in dataset = 160
# Current position in dataset after next_batch = 13
# Added new weapon/s! New number of examples in dataset = 161
# Current position in dataset after next_batch = 14
# Added new weapon/s! New number of examples in dataset = 162
# Current position in dataset after next_batch = 15
# Added new weapon/s! New number of examples in dataset = 163
# Current position in dataset after next_batch = 16
# Added new weapon/s! New number of examples in dataset = 164
# Current position in dataset after next_batch = 17
# Added new weapon/s! New number of examples in dataset = 165
# Current position in dataset after next_batch = 18
# Added new weapon/s! New number of examples in dataset = 166
# Current position in dataset after next_batch = 19
# Added new weapon/s! New number of examples in dataset = 167
# Current position in dataset after next_batch = 20
# Added new weapon/s! New number of examples in dataset = 168
# Current position in dataset after next_batch = 21
# Added new weapon/s! New number of examples in dataset = 169
# Current position in dataset after next_batch = 22
# Added new weapon/s! New number of examples in dataset = 170
# Current position in dataset after next_batch = 23
# Added new weapon/s! New number of examples in dataset = 171
# Current position in dataset after next_batch = 24
# Added new weapon/s! New number of examples in dataset = 172
# Current position in dataset after next_batch = 25
# Added new weapon/s! New number of examples in dataset = 173
# Current position in dataset after next_batch = 26
# Added new weapon/s! New number of examples in dataset = 174
# Current position in dataset after next_batch = 27
# Added new weapon/s! New number of examples in dataset = 175
# Current position in dataset after next_batch = 28
# Added new weapon/s! New number of examples in dataset = 176
# Current position in dataset after next_batch = 29
# Added new weapon/s! New number of examples in dataset = 177
# Current position in dataset after next_batch = 30
# Added new weapon/s! New number of examples in dataset = 178
# Current position in dataset after next_batch = 31
# Added new weapon/s! New number of examples in dataset = 179
# Current position in dataset after next_batch = 32
# Added new weapon/s! New number of examples in dataset = 180
# Current position in dataset after next_batch = 33
# Added new weapon/s! New number of examples in dataset = 181
# Current position in dataset after next_batch = 34
# Added new weapon/s! New number of examples in dataset = 182
# Current position in dataset after next_batch = 35
# Added new weapon/s! New number of examples in dataset = 183
# Current position in dataset after next_batch = 36
# Added new weapon/s! New number of examples in dataset = 184
# Current position in dataset after next_batch = 37
# Added new weapon/s! New number of examples in dataset = 185
# Current position in dataset after next_batch = 38
# Added new weapon/s! New number of examples in dataset = 186
# Current position in dataset after next_batch = 39
# Added new weapon/s! New number of examples in dataset = 187
# Current position in dataset after next_batch = 40
# Added new weapon/s! New number of examples in dataset = 188
# Current position in dataset after next_batch = 41
# Added new weapon/s! New number of examples in dataset = 189
# Current position in dataset after next_batch = 42
# Added new weapon/s! New number of examples in dataset = 190
# Current position in dataset after next_batch = 43
# Added new weapon/s! New number of examples in dataset = 191
# Current position in dataset after next_batch = 44
# Added new weapon/s! New number of examples in dataset = 192
# Current position in dataset after next_batch = 45
# Added new weapon/s! New number of examples in dataset = 193
# Current position in dataset after next_batch = 46
# Added new weapon/s! New number of examples in dataset = 194
# Current position in dataset after next_batch = 47
# Added new weapon/s! New number of examples in dataset = 195
# Current position in dataset after next_batch = 48
# Added new weapon/s! New number of examples in dataset = 196
# Current position in dataset after next_batch = 49
# Added new weapon/s! New number of examples in dataset = 197
# Current position in dataset after next_batch = 50
# Added new weapon/s! New number of examples in dataset = 198
# Current position in dataset after next_batch = 51
# Added new weapon/s! New number of examples in dataset = 199
# Current position in dataset after next_batch = 52
# Added new weapon/s! New number of examples in dataset = 200
# Current position in dataset after next_batch = 53
# Added new weapon/s! New number of examples in dataset = 201
# Current position in dataset after next_batch = 54
# Added new weapon/s! New number of examples in dataset = 202
# Current position in dataset after next_batch = 55
# Added new weapon/s! New number of examples in dataset = 203
# Current position in dataset after next_batch = 56
# Added new weapon/s! New number of examples in dataset = 204
# Current position in dataset after next_batch = 57
# Added new weapon/s! New number of examples in dataset = 205
# Current position in dataset after next_batch = 58
# Added new weapon/s! New number of examples in dataset = 206
# Current position in dataset after next_batch = 59
# Added new weapon/s! New number of examples in dataset = 207
# Current position in dataset after next_batch = 60
# Added new weapon/s! New number of examples in dataset = 208
# Current position in dataset after next_batch = 61
# Added new weapon/s! New number of examples in dataset = 209
# Current position in dataset after next_batch = 62
# Added new weapon/s! New number of examples in dataset = 210
# Current position in dataset after next_batch = 63
# Added new weapon/s! New number of examples in dataset = 211
# Current position in dataset after next_batch = 64
# Added new weapon/s! New number of examples in dataset = 212
# Current position in dataset after next_batch = 65
# Added new weapon/s! New number of examples in dataset = 213
# Current position in dataset after next_batch = 66
# Added new weapon/s! New number of examples in dataset = 214
# Current position in dataset after next_batch = 67
# Added new weapon/s! New number of examples in dataset = 215
# Current position in dataset after next_batch = 68
# Added new weapon/s! New number of examples in dataset = 216
# Current position in dataset after next_batch = 69
# Added new weapon/s! New number of examples in dataset = 217
# Current position in dataset after next_batch = 70
# Added new weapon/s! New number of examples in dataset = 218
# Current position in dataset after next_batch = 71
# Added new weapon/s! New number of examples in dataset = 219
# Current position in dataset after next_batch = 72
# Added new weapon/s! New number of examples in dataset = 220
# Current position in dataset after next_batch = 73
# Added new weapon/s! New number of examples in dataset = 221
# Current position in dataset after next_batch = 74
# Added new weapon/s! New number of examples in dataset = 222
# Current position in dataset after next_batch = 75
# Added new weapon/s! New number of examples in dataset = 223
# Current position in dataset after next_batch = 76
# Added new weapon/s! New number of examples in dataset = 224
# Current position in dataset after next_batch = 77
# Added new weapon/s! New number of examples in dataset = 225
# Current position in dataset after next_batch = 78
# Added new weapon/s! New number of examples in dataset = 226
# Current position in dataset after next_batch = 79
# Added new weapon/s! New number of examples in dataset = 227
# Current position in dataset after next_batch = 80
# Added new weapon/s! New number of examples in dataset = 228
# Current position in dataset after next_batch = 81
# Added new weapon/s! New number of examples in dataset = 229
# Current position in dataset after next_batch = 82
# Added new weapon/s! New number of examples in dataset = 230
# Current position in dataset after next_batch = 83
# Added new weapon/s! New number of examples in dataset = 231
# Current position in dataset after next_batch = 84
# Added new weapon/s! New number of examples in dataset = 232
# Current position in dataset after next_batch = 85
# Added new weapon/s! New number of examples in dataset = 233
# Current position in dataset after next_batch = 86
# Added new weapon/s! New number of examples in dataset = 234
# Current position in dataset after next_batch = 87
# Added new weapon/s! New number of examples in dataset = 235
# Current position in dataset after next_batch = 88
# Added new weapon/s! New number of examples in dataset = 236
# Current position in dataset after next_batch = 89
# Added new weapon/s! New number of examples in dataset = 237
# Current position in dataset after next_batch = 90
# Added new weapon/s! New number of examples in dataset = 238
# Current position in dataset after next_batch = 91
# Added new weapon/s! New number of examples in dataset = 239
# Current position in dataset after next_batch = 92
# Added new weapon/s! New number of examples in dataset = 240
# Current position in dataset after next_batch = 93
# Added new weapon/s! New number of examples in dataset = 241
# Current position in dataset after next_batch = 94
# Added new weapon/s! New number of examples in dataset = 242
# Current position in dataset after next_batch = 95
# Added new weapon/s! New number of examples in dataset = 243
# Current position in dataset after next_batch = 96
# Added new weapon/s! New number of examples in dataset = 244
# Current position in dataset after next_batch = 97
# Added new weapon/s! New number of examples in dataset = 245
# Current position in dataset after next_batch = 98
# Added new weapon/s! New number of examples in dataset = 246
# Current position in dataset after next_batch = 99
# Added new weapon/s! New number of examples in dataset = 247
# Current position in dataset after next_batch = 100
# Added new weapon/s! New number of examples in dataset = 248
# damages_first = ['28.0']
# damages_last = ['21.0']
# dmg_distances_first = ['11.0']
# dmg_distances_last = ['35.0']
# drag = ['0.0025']
# firemode_Automatic = ['1.0']
# firemode_Semi-Automatic = ['0.0']
# hiprecoildec = ['6.0']
# hiprecoilright = ['0.275']
# hiprecoilup = ['0.38']
# hordispersion = ['0.0']
# initialspeed = ['800.0']
# magsize = ['30.0']
# reloadempty = ['4.2']
# rof = ['540.0']
# shotspershell = ['1.0']
# type_Shotgun = ['0.0']
# type_Pistol = ['0.0']
# type_Rifle = ['0.0']
# type_Submachine Gun = ['0.0']
# type_Sniper Rifle = ['0.0']
# verdispersion = ['0.0']
